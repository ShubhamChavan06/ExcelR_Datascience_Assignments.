# %% [markdown]
# # Perform sentimental analysis on the Elon-musk tweets

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('E://EXCELR//Data science//Data science assignment//11) Text Mining//Elon_musk.csv',encoding='cp1252')
df.head()
# Out:
#    Unnamed: 0                                               Text
# 0           1                             @kunalb11 I’m an alien
# 1           2  @ID_AA_Carmack Ray tracing on Cyberpunk with H...
# 2           3                @joerogan @Spotify Great interview!
# 3           4                    @gtera27 Doge is underestimated
# 4           5  @teslacn Congratulations Tesla China for amazi...

# %%
df.shape
# Out:
# (1999, 2)

# %%
print("Total tweets in given corpus:",df.shape[0])
# Out:
# Total tweets in given corpus: 1999

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# Text          object
# dtype: object

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
pd.set_option('max_colwidth',500)
df.head(10)
# Out:
#                                                                                                        Text
# 0                                                                                    @kunalb11 I’m an alien
# 1                        @ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?
# 2                                                                       @joerogan @Spotify Great interview!
# 3                                                                           @gtera27 Doge is underestimated
# 4  @teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!
# 5                                                         Happy New Year of the Ox! https://t.co/9WFKMYu2oj
# 6        Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM
# 7                                                            @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)
# 8                 @flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.
# 9                                                          The most entertaining outcome is the most likely

# %%
df['Cleaned_text']=[x.strip()for x in df['Text']]

# %%
df.head(10)
# Out:
#                                                                                                        Text  \
# 0                                                                                    @kunalb11 I’m an alien
# 1                        @ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?
# 2                                                                       @joerogan @Spotify Great interview!
# 3                                                                           @gtera27 Doge is underestimated
# 4  @teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!
# 5                                                         Happy New Year of the Ox! https://t.co/9WFKMYu2oj
# 6        Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM
# 7                                                            @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)
# 8                 @flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.
# 9                                                          The most entertaining outcome is the most likely
#
#                                                                                                Cleaned_text
# 0                                                                                    @kunalb11 I’m an alien
# 1                        @ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?
# 2                                                                       @joerogan @Spotify Great interview!
# 3                                                                           @gtera27 Doge is underestimated
# 4  @teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!
# 5                                                         Happy New Year of the Ox! https://t.co/9WFKMYu2oj
# 6        Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM
# 7                                                            @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)
# 8                 @flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.
# 9                                                          The most entertaining outcome is the most likely

# %%
## Converting to lower case

df['Cleaned_text']=[x.lower()for x in df.Text]
df.head(10)
# Out:
#                                                                                                        Text  \
# 0                                                                                    @kunalb11 I’m an alien
# 1                        @ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?
# 2                                                                       @joerogan @Spotify Great interview!
# 3                                                                           @gtera27 Doge is underestimated
# 4  @teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!
# 5                                                         Happy New Year of the Ox! https://t.co/9WFKMYu2oj
# 6        Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM
# 7                                                            @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)
# 8                 @flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.
# 9                                                          The most entertaining outcome is the most likely
#
#                                                                                                Cleaned_text
# 0                                                                                    @kunalb11 i’m an alien
# 1                        @id_aa_carmack ray tracing on cyberpunk with hdr is next-level. have you tried it?
# 2                                                                       @joerogan @spotify great interview!
# 3                                                                           @gtera27 doge is underestimated
# 4  @teslacn congratulations tesla china for amazing execution last year. now on to the next for even more!!
# 5                                                         happy new year of the ox! https://t.co/9wfkmyu2oj
# 6        frodo was the underdoge,\nall thought he would fail,\nhimself most of all. https://t.co/zgxjfdzzrm
# 7                                                            @owensparks_ @flcnhvy @anonyx10 haha thanks :)
# 8                 @flcnhvy @anonyx10 indeed! tweets definitely do not represent real-world time allocation.
# 9                                                          the most entertaining outcome is the most likely

# %%
## Importing RegEx module
import re

# %%
## Removing all urls from text

df['Cleaned_text']=[re.sub(r'http\S+', '',x, flags=re.MULTILINE)for x in df.Cleaned_text]

df.head(10)
# Out:
#                                                                                                        Text  \
# 0                                                                                    @kunalb11 I’m an alien
# 1                        @ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?
# 2                                                                       @joerogan @Spotify Great interview!
# 3                                                                           @gtera27 Doge is underestimated
# 4  @teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!
# 5                                                         Happy New Year of the Ox! https://t.co/9WFKMYu2oj
# 6        Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM
# 7                                                            @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)
# 8                 @flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.
# 9                                                          The most entertaining outcome is the most likely
#
#                                                                                                Cleaned_text
# 0                                                                                    @kunalb11 i’m an alien
# 1                        @id_aa_carmack ray tracing on cyberpunk with hdr is next-level. have you tried it?
# 2                                                                       @joerogan @spotify great interview!
# 3                                                                           @gtera27 doge is underestimated
# 4  @teslacn congratulations tesla china for amazing execution last year. now on to the next for even more!!
# 5                                                                                happy new year of the ox!
# 6                               frodo was the underdoge,\nall thought he would fail,\nhimself most of all.
# 7                                                            @owensparks_ @flcnhvy @anonyx10 haha thanks :)
# 8                 @flcnhvy @anonyx10 indeed! tweets definitely do not represent real-world time allocation.
# 9                                                          the most entertaining outcome is the most likely

# %%
## Removing twitter handles from text

df['Cleaned_text']=[re.sub('@[^\s]+','',x)for x in df.Cleaned_text]

df.head(10)
# Out:
#                                                                                                        Text  \
# 0                                                                                    @kunalb11 I’m an alien
# 1                        @ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?
# 2                                                                       @joerogan @Spotify Great interview!
# 3                                                                           @gtera27 Doge is underestimated
# 4  @teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!
# 5                                                         Happy New Year of the Ox! https://t.co/9WFKMYu2oj
# 6        Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM
# 7                                                            @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)
# 8                 @flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.
# 9                                                          The most entertaining outcome is the most likely
#
#                                                                                        Cleaned_text
# 0                                                                                      i’m an alien
# 1                               ray tracing on cyberpunk with hdr is next-level. have you tried it?
# 2                                                                                  great interview!
# 3                                                                            doge is underestimated
# 4   congratulations tesla china for amazing execution last year. now on to the next for even more!!
# 5                                                                        happy new year of the ox!
# 6                       frodo was the underdoge,\nall thought he would fail,\nhimself most of all.
# 7                                                                                    haha thanks :)
# 8                            indeed! tweets definitely do not represent real-world time allocation.
# 9                                                  the most entertaining outcome is the most likely

# %%
## Removing numbers and special characters

df['Cleaned_text']=[re.sub('[^A-Za-z ]+','',x)for x in df.Cleaned_text]

df.head(10)
# Out:
#                                                                                                        Text  \
# 0                                                                                    @kunalb11 I’m an alien
# 1                        @ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?
# 2                                                                       @joerogan @Spotify Great interview!
# 3                                                                           @gtera27 Doge is underestimated
# 4  @teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!
# 5                                                         Happy New Year of the Ox! https://t.co/9WFKMYu2oj
# 6        Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM
# 7                                                            @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)
# 8                 @flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.
# 9                                                          The most entertaining outcome is the most likely
#
#                                                                                     Cleaned_text
# 0                                                                                    im an alien
# 1                               ray tracing on cyberpunk with hdr is nextlevel have you tried it
# 2                                                                                great interview
# 3                                                                         doge is underestimated
# 4   congratulations tesla china for amazing execution last year now on to the next for even more
# 5                                                                      happy new year of the ox
# 6                           frodo was the underdogeall thought he would failhimself most of all
# 7                                                                                   haha thanks
# 8                            indeed tweets definitely do not represent realworld time allocation
# 9                                               the most entertaining outcome is the most likely

# %%
## Removing short words of length 3 or less

short = re.compile(r'\W*\b\w{1,3}\b')
df['Cleaned_text']=[short.sub('',x)for x in df.Cleaned_text]

df.head(10)
# Out:
#                                                                                                        Text  \
# 0                                                                                    @kunalb11 I’m an alien
# 1                        @ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?
# 2                                                                       @joerogan @Spotify Great interview!
# 3                                                                           @gtera27 Doge is underestimated
# 4  @teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!
# 5                                                         Happy New Year of the Ox! https://t.co/9WFKMYu2oj
# 6        Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM
# 7                                                            @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)
# 8                 @flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.
# 9                                                          The most entertaining outcome is the most likely
#
#                                                               Cleaned_text
# 0                                                                    alien
# 1                              tracing cyberpunk with nextlevel have tried
# 2                                                          great interview
# 3                                                      doge underestimated
# 4   congratulations tesla china amazing execution last year next even more
# 5                                                              happy year
# 6                       frodo underdogeall thought would failhimself most
# 7                                                             haha thanks
# 8             indeed tweets definitely represent realworld time allocation
# 9                                    most entertaining outcome most likely

# %%
## Removing StopWords

import nltk
from nltk.corpus import stopwords

## Loading stopwords 
my_stopwords = stopwords.words('english')

# %%
df['Cleaned_text'] = df['Cleaned_text'].apply(lambda x: ' '.join([item for item in x.split() if item not in my_stopwords]))

# %%
df.head(10)
# Out:
#                                                                                                        Text  \
# 0                                                                                    @kunalb11 I’m an alien
# 1                        @ID_AA_Carmack Ray tracing on Cyberpunk with HDR is next-level. Have you tried it?
# 2                                                                       @joerogan @Spotify Great interview!
# 3                                                                           @gtera27 Doge is underestimated
# 4  @teslacn Congratulations Tesla China for amazing execution last year. Now on to the next for even more!!
# 5                                                         Happy New Year of the Ox! https://t.co/9WFKMYu2oj
# 6        Frodo was the underdoge,\nAll thought he would fail,\nHimself most of all. https://t.co/zGxJFDzzrM
# 7                                                            @OwenSparks_ @flcnhvy @anonyx10 Haha thanks :)
# 8                 @flcnhvy @anonyx10 Indeed! Tweets definitely do not represent real-world time allocation.
# 9                                                          The most entertaining outcome is the most likely
#
#                                                         Cleaned_text
# 0                                                              alien
# 1                                  tracing cyberpunk nextlevel tried
# 2                                                    great interview
# 3                                                doge underestimated
# 4  congratulations tesla china amazing execution last year next even
# 5                                                         happy year
# 6                       frodo underdogeall thought would failhimself
# 7                                                        haha thanks
# 8       indeed tweets definitely represent realworld time allocation
# 9                                        entertaining outcome likely

# %% [markdown]
# # Lemmatization

# %%
tweets_merge = [x.strip() for x in df.Cleaned_text] # remove both the leading and the trailing characters
tweets_merge
# Out:
# ['alien',
#  'tracing cyberpunk nextlevel tried',
#  'great interview',
#  'doge underestimated',
#  'congratulations tesla china amazing execution last year next even',
#  'happy year',
#  'frodo underdogeall thought would failhimself',
#  'haha thanks',
#  'indeed tweets definitely represent realworld time allocation',
#  'entertaining outcome likely',
#  'sent',
#  'agree clubhouse',
#  '',
#  'getting real',
#  'bought dogecoin toddler hodler',
#  'definitely issues sentencing seems high',
#  'thanks fixing',
#  'please unlock account',
#  'ufuf',
#  'true power haha',
#  'crypto wallet wont give private keys avoided costs',
#  'sucks',
#  'nasa selected falcon heavy launch first elements lunar gateway together mission',
#  '',
#  'predict cash flow reasonably well starlink',
#  'starlink staggeringly difficult technical economic endeavor however',
#  'spacex needs pass deep chasm negative cash flow next year',
#  'lowest cost carbon sequestered value product made must scalable',
#  'meant price countries difference taxes shipping',
#  'intended earth ideas apply mars',
#  'ufuf',
#  'xprize team manage carbon capture prize',
#  'everyone tesla receives stock comp stockoptions take table thats youre missing',
#  'back work',
#  'seem high',
#  'doge appears inflationary meaningfully fixed coins unit time whereas',
#  '',
#  'orbital launch tower stack enough raptors orbit booster improve ship booster mass',
#  'back work tonight',
#  'ogecoin instructional video',
#  'people spoken',
#  'cute',
#  'extremely misleading image doesnt reflect true time cost people rain pain',
#  'doge',
#  'hodl rainforests',
#  'finally come',
#  'crypto',
#  'simplicity genius',
#  '',
#  'ufuf',
#  'true',
#  'ufuf',
#  'easy decades intense work look notes emails texts',
#  '',
#  'lessons learned',
#  'earth mars',
#  'time tell story tesla spacex',
#  'read great',
#  'second last kingdom',
#  'havent heard name years',
#  'dogecake',
#  'yolt',
#  'thats damian',
#  'yeah',
#  'sure',
#  'great thing restaurants hang strangers',
#  'future currency earth',
#  'scratch',
#  'much',
#  '',
#  'destiny',
#  'franz essential',
#  'said ship landing burn clear solution greate',
#  'still maneuvering thrusters',
#  'higher',
#  'intuitively would seem turbopumpfed raptors',
#  '',
#  'falcon launch spherex mission collect data million galaxies explore',
#  'falcon launches starlink satellites orbit mission deck',
#  'true',
#  'yeah default engine least lever would shut good',
#  'engines throttle point flameout risk',
#  '',
#  'foolish start engines immediately shut needed land',
#  'become memedestroyer shorts',
#  'might actually happen',
#  'sandstorm masterpiece',
#  'dumb',
#  'next time pull method',
#  'lowkey loki',
#  'highs lows doge',
#  'need gigachad',
#  'dogecoin peoples crypto',
#  'welcome',
#  'entertaining outcome likely',
#  'doge',
#  '',
#  'high seas wind',
#  'tough',
#  'watch falcon launch starlink satellites',
#  'twitter',
#  'filled graffiti',
#  'ucub uuuubuuuc',
#  'giga berlin progress',
#  'neuralink working super hard ensure implant safety close communication',
#  'mission enables access everyday people dream going space',
#  'announcing first commercial astronaut mission orbit earth aboard dragon',
#  'youve worked advanced wearables phones robots skills needed',
#  'feels weird helping make hopefully good version cyberpunk come true',
#  'please consider working neuralinkshortterm solve brainspine injurieslongterm humanai symbiosis latte',
#  '',
#  'clubhouse tonight time',
#  'great stories experim',
#  'launch alert targeting earlier april launch second crew rotation',
#  'became methane',
#  'sounds correct certainly deserves',
#  'great instrumental developing early vers',
#  'accelerate unusually fast high important reusable',
#  'escaping',
#  'read whole article ufuf',
#  'warm sunny snowy mountains',
#  'beautiful',
#  'yeah frankensteen',
#  'never used gave talk spacex',
#  'halo',
#  '',
#  'sure hope thats true tesla spacex',
#  'cryoproof install engines',
#  'starship',
#  'retrospect inevitable',
#  'great shot',
#  'live sword sword',
#  'entropy',
#  'hold companies make goods produce services love',
#  'earth small smaller still',
#  '',
#  'cyberpunk even hotfixes literally hotfixes great game',
#  '',
#  'dollar shorting',
#  'indeed',
#  'shopify great spacex used',
#  'ufuf',
#  'indeed economy making useful products providing great services actually matters',
#  'tanstaafl would better small fees fees latter makes robin',
#  'come shorty apologistsgive respectget shorty',
#  'cant sell houses dont ownu cant sell cars dont ownbut sell stock dont ownthis',
#  '',
#  'finishing engineering year production starts next year aiming release candidate desig',
#  'made video',
#  'absolutely',
#  'unlike aircraft division fine space division fundamentally broken',
#  'nomad',
#  '',
#  'esthetics cyberpunk incredible interior design isufc',
#  'major esthetics improvements coming',
#  'little',
#  'roadster part rocket',
#  'theres storage easily upgradable',
#  '',
#  '',
#  'yeah probably months',
#  'drive without using prnd stalkstick days gets annoying back shifter',
#  'stalks guesses drive direction based obstacles sees context',
#  'hedge fund shorts shrubbery',
#  '',
#  'yeah also rear screen',
#  'trap speed mile speed right tires',
#  'first production ever achieve less seconds',
#  'play cyberpunk',
#  'plaid model ships next month',
#  'even discord gone corpo',
#  'wild times discord haha',
#  '',
#  'waiting review',
#  'gamestonk',
#  'passed initial pressure test',
#  '',
#  '',
#  'bought hand knit wool marvin martian helm',
#  '',
#  'kinda love etsy',
#  'serve public hamstring starlink today amazon satellite system',
#  'hoping approval test flight tomorrow afternoon',
#  'entire stack data collection labeling inference surround video',
#  'although crazy turn',
#  'tesla steadily moving camera surround video enable superhuman selfdriving',
#  'tyranny also road hell mostly paved intentions',
#  'catchy',
#  'sats launched next year laser links',
#  '',
#  'hope',
#  'also laser links satellites ground stations needed poles',
#  'sorry version confusion separate version number rest',
#  'surprise tesla better hardware software waymo money',
#  'floats',
#  'falloutthemed opening party vegas loop happening soon allowed',
#  'ufuf',
#  'vegas tunnel yesterday boys',
#  'lasers',
#  'spacexs rideshare offering provides increased access space small satellite operators seeking reliable affordable',
#  'falcon first stage landed course still love droneship',
#  'liftoff',
#  'ufaf',
#  'switching sensible version numbering distinguish major minor updates',
#  'hopefully early next week',
#  'unfavorable weather standing todays launch team continue countdown seco',
#  'given many companies depending mission getting even scru',
#  'launching many small satellites wide range customers tomorrow excited offering lowcost access',
#  'part solution require lots fresh water land need something thats',
#  '',
#  'good path fully renewable rocket energy solves part problem longer chain',
#  'details next week',
#  'donating towards prize best carbon capture technology',
#  'pretty much',
#  'would probably mean civilization',
#  '',
#  'absolutely rock',
#  'falcon launches starlink orbit eighth launch landing booster',
#  'ratelimiting part process cell production constantly changing',
#  'cars trucks stuck traffic generate megatons toxic gases particulate',
#  'giant casting machines literally trying make fullsize',
#  'tegmark exceptionally smart good human',
#  'best manufacturing technology ultra high volume industries like food beverage medical syringes toys',
#  'battery cell production fundamental ratelimiter slowing sustainable energy future important',
#  'looking question viewed reasonably valuable tradein',
#  'sure',
#  'glad youre',
#  'congratulations',
#  'good',
#  'whistle',
#  'cybertruck doesnt need garage',
#  'awesome',
#  'good point',
#  'serverside code much',
#  'happy birthday wikipedia glad exist',
#  'guess watching cobra',
#  'fallout texas',
#  'chuck norris divide zero',
#  'good point',
#  'thing call money information system labor allocation actuall',
#  'monty python amazing',
#  'sure twist knife show',
#  'probably wise',
#  'making major improvements ease engine swap needs hours',
#  'engines need slight repairs switched',
#  'nice shot',
#  'dont high school internships please apply youre college',
#  'prototypes easy volume production hard positive cash flow excruciating',
#  'physics',
#  'splashdown dragon confirmed completing spacexs resupply mission first return cargo resupp',
#  'detanking inspections good progress towards mars goal',
#  'three static fires completed ruds',
#  'happened years',
#  'fair enough haha',
#  '',
#  'shanty tiktok takes level actual pirate ships',
#  'sure',
#  'today spacex practicing starship engine starts ship held massive pins engines',
#  'promised',
#  'legalize comedy',
#  'steal namelogos probably wont',
#  'trying people mars help would appreciated',
#  'camera also shows star field background',
#  'separation confirmed dragon performing departure burns move away',
#  'suicide double homicide',
#  'absolutely',
#  'yeah queen youre gonna make ufuf',
#  'hate might true',
#  'robot future coming',
#  'every millisecond times wish faster',
#  '',
#  '',
#  'protec yoda',
#  'ueud uubub uuubuuaueubuufuud',
#  'important distinction',
#  'much increasing rapidly',
#  '',
#  'something happens even better imagined',
#  'factory product',
#  'probably commenting',
#  'bought replacement glass junkyard theyre great places spare parts',
#  'people going super unhappy west coast high tech facto arbiter free speech',
#  'already donated signal year donate',
#  'primarily trying advance causes sustainable energy extending lifeconsciousness beyond',
#  'ufuf',
#  'maybe tesla later year',
#  'prancing pony',
#  'ufuf',
#  '',
#  'true',
#  'long',
#  'yeah seemed optimistic',
#  'yearold saxon said feels like good year agree make',
#  'also thinking spacex boca hold parties give tours community time time',
#  'super support public spaces around production launch sites wherever done',
#  '',
#  'catapult high land roof base jumping parachute travel',
#  'thats actually restaurant spacex building futuristic',
#  'increase hopefully',
#  'neither',
#  'best tesla solar roof installations',
#  'maybe',
#  'would best large solar field reactor needed',
#  'sick beats',
#  'probably less dozen primary decisionmakers technically three',
#  'least option verification public ascribe credibilit',
#  'launch underway',
#  'critical feedback always super appreciated well ways donate money really make difference harder seems',
#  '',
#  'indirectly electric rocket possible using electricity convert coho',
#  'orbit unfortunately space photon emission powered matterantimatter annihila',
#  'hard make isnt like vehicle',
#  'playing long game',
#  'true',
#  'hope wings dont work moon well mars also runways',
#  'hamiltonians potential langrangians play',
#  '',
#  'well back work',
#  'strange',
#  'signal',
#  'dont reminds timeless classic',
#  'fast water tiny rocks',
#  'occams razor actually third likely',
#  'seen external observer participants',
#  'entertaining outcome likely',
#  'dumb dumber great movie',
#  'called domino effect',
#  '',
#  'large footprint seem flat actually ranges stories tall',
#  'snow falling giga berlin',
#  '',
#  '',
#  'tesla responsible personal professional pain life combined worth',
#  'proud tesla team achieving major milestone start tesla thought optimistica',
#  'produced delivered half million cars huge thanks made possible',
#  'giant fusion reactor works maintenance',
#  'tesla full selfdriving work safety level well average driver year',
#  'dojo isnt needed make selfdriving better isnt enough safer human drivers',
#  'ignore heading',
#  'great interview mathias dpfner',
#  'greatest gatsby',
#  'inspired ballet',
#  'rocket motion primarily vertical want open',
#  'lets make roaring',
#  'might lumps along',
#  'production hard prototypes easy building starships create',
#  'exactly',
#  'haha',
#  'press header tank helium longterm solution debate',
#  '',
#  'legs would certainly work best part part best step step',
#  '',
#  'saves mass cost legs enables immediate repositioning booster launch mount',
#  'going catch super heavy booster launch tower using grid fins take load',
#  'snakehead undivided attention winderhead ostrich came gliding nonchalant',
#  'seems opposition group bmws home state baveria thats brande',
#  'sensible opposition anywhere cannot mean progress everywhere',
#  'literally',
#  'sure real',
#  'destiny destinyno escaping',
#  'tesla cars delivered final three days year three months full selfdriving option',
#  'mark dankberg action wack dank',
#  'less',
#  'westworld',
#  'last kingdom show great',
#  'absolutely text visualization could voice',
#  'even cheese made cake',
#  'dont love deep trouble',
#  'everything made cake',
#  'true haha',
#  'weird game think',
#  '',
#  'need overhaul',
#  'incremental improvements production codebase build',
#  'starlink poses hazard viasats profits like stop sneaky moves charlie ergen',
#  'entertainment critical cars drive',
#  'meeting larry ellison seek advice back working tesla quarter tomorrow',
#  'absolutely',
#  'tesla incar gaming autonomous world',
#  'absolutely',
#  'taste future',
#  'playing polytopia tesla great game multiplayer online version coming soon',
#  'focus making products services people truly love total economic bigger instead',
#  'roughly parts tesla roadster unique',
#  '',
#  'important',
#  'service might able check',
#  'mean install external speaker earlier cars dont',
#  'definitely year',
#  'good point',
#  'interesting',
#  'always done great interviews',
#  'falcon successful orbital launches maybe majority',
#  'vaccines start also capable theory curing almost anything turns medicine',
#  '',
#  'offer multiple display options',
#  'revisions needed probably beta',
#  'sure',
#  'haha',
#  'subtle important differences canada traffic rules',
#  '',
#  'need match traffic speed setting',
#  'definitely',
#  'step direction',
#  'dont pedestrian speaker couldnt everything done',
#  'writing cobra sickufc',
#  'haha save nightmare seeing shorts',
#  'upload custom musicsounds',
#  'unfortunately pedestrian speaker needed otherwise external sound generator except actual horn',
#  'change horn sound ufdufb holiday jingles latest tesla software update',
#  'merry christmas happy holidays',
#  'great game',
#  'likely make sense starlink public revenue growth reasonably predictable',
#  'engineering design general company operations absorb vast majority mind fundamental',
#  '',
#  'months',
#  'coming soon',
#  'minor',
#  'yeah',
#  'story rocket turns engines controlled fall',
#  'ironing bugs',
#  'tesla owners taking delivery final days year support super appreciated',
#  'frictionless could possibly wrong',
#  'good idea',
#  'darkest days model program reached cook discuss possibility',
#  'strange true tesla already uses ironphosphate medium range cars made shanghai facto',
#  'spartas reply macedon',
#  '',
#  'thanks everyone worked hard make tesla successful heart goes',
#  'indeed',
#  'seriously twisted affair alls ends well',
#  'although kind lowkey tesla superchargers made accessible electric cars',
#  'photos yesterdays launch landing',
#  'large transactions even possible',
#  'uufef love crazy uufef',
#  'point sigh',
#  'great game',
#  'pretty much main value college used hanging pseudo intellectual conversations',
#  'come comments stay memesuf',
#  'absolutely release subscription early next year',
#  'word doge',
#  'bitcoin almost fiat money',
#  'great nails lipstick',
#  '',
#  '',
#  'sounds right',
#  'lord edge',
#  'nice branding',
#  'kidding needs safe word anyway',
#  'bitcoin safe word',
#  'falcon first stage landed landing zone',
#  'liftoff',
#  'standing today inspect rocket hopefully launching tomorrow',
#  'pressure slightly high upper stage liquid oxygen tank review underway',
#  'hoping back next month',
#  'impressive mission china',
#  'last launch coming',
#  'indeed quite grumpy actually know point',
#  'absurdly good tesla aiautopilot engineering awesome theres great ther',
#  'star light star bright',
#  'incorrect',
#  'ufuf',
#  'visually stunning playability good',
#  'tshirt better armor kevlar chest plate doesnt make sense absence magic also',
#  '',
#  'absolutely support trans pronouns esthetic nightmare',
#  'raptors well thrust ship would blown altit',
#  'fully loaded going slow ship would gone crazy highfar three engines',
#  'good great game improving seem like mere surface detail woul',
#  'perhaps slightly confident essential view output time',
#  'dankeschn brandenburg grnheide',
#  'sure hope future doesnt come pass',
#  'giga berlinbrandenburg first structural pack architecture worlds',
#  'original deus incredible human revolution also great',
#  'objective reality impossible advanced game well hardware',
#  'starship landing flip maneuver',
#  '',
#  'ascent heavens',
#  '',
#  'yeah briefly seems pretty good picked nomad start little slow picks',
#  '',
#  'hehe',
#  '',
#  '',
#  '',
#  '',
#  'falcon launches orbit completing spacexs launch year',
#  'init void',
#  'cooling haha',
#  'still soft spot heart transpiration cooking theory would',
#  'ship leeward side bare metal windward black hexagonal heat shield tiles',
#  'cant wait spacex spacexstarship',
#  '',
#  'agreed preserved memory',
#  'photos starship flight test',
#  'exactly woohoo',
#  'great even reaching apogee wouldve great controlling putting',
#  'thank south texas support gateway mars',
#  'life universe everything',
#  'yeah engines great',
#  'mars come',
#  'fuel header tank pressure landing burn causing touchdown velocity high',
#  'successful ascent switchover header tanks precise flap control landing point',
#  '',
#  'nearorbital space fastest travel long distance earth',
#  'called space station actually moving around earth times spee',
#  'timelapse dragon approach dragons docked',
#  'long thanks orifice alien message decrypted',
#  'probably chance completing mission objectives',
#  'hopefully flying tomorrow',
#  '',
#  'success upgraded dragon cargo spacecraft autonomously docked',
#  'south texas',
#  'station dragon going orbital night period docking crewdragon',
#  'station looks amazing',
#  'good morning earthlings uufef journey continues watch nasa cargo resupply mission docks',
#  'knock knock singing telegram',
#  'carrying even symbiotic bacteria trillion cells',
#  '',
#  'mobile cell colonies',
#  '',
#  'tracking footage helicopter todays falcon launch',
#  'theres something genuinely magical seeing starship person boca chica beautiful quiet serine',
#  'gesprch mathias dpfner',
#  'dragon separation confirmed spacecraft autonomous docking tomorrow approximately',
#  'falcon booster landed course still love droneship',
#  'liftoff',
#  'congratulations',
#  'congratulations',
#  '',
#  'tunnel rave',
#  'toilet paper ufuf',
#  'watch demolition',
#  'prometheus unbound',
#  'falcon booster supporting mission previously launched astronauts behnken doug hurley',
#  '',
#  'beast compared',
#  'award accepted behalf great people tesla spacex neuralink boring',
#  'much people think science actually engineering thing rocket scientist',
#  'science discovering essential truths exists universe engineering creating things',
#  'cold night',
#  'paint makes hell difference',
#  'congrats',
#  'thanks everything help build spacex best memories ever',
#  'real soon',
#  'starship legs hardest problems external',
#  'static fire risky build site need clear build site early flights',
#  'static fire tomorrow flight earlier wednesday',
#  'landing legs',
#  'news tony great',
#  'second thought thanos haha',
#  'yeah truncate zeros round',
#  'probably going wider beta weeks',
#  'least important digits truncated feels like betting training dojo',
#  'almost heavy lifting inference works great',
#  'actually',
#  '',
#  'happy thanksgiving',
#  'hopefully next month',
#  'overall suspension height damping algorithm',
#  'haha true',
#  'promise greatly needed',
#  'special colors roadster original',
#  'ufuf',
#  'savage ufuf',
#  'ever wondered came',
#  'life leader launch risk normal',
#  'slightly filled',
#  'subject much debate',
#  'major upgrades slated',
#  'many small improvements overall similar wiring robust engines',
#  'thats',
#  'things need right maybe chance',
#  'good starship static fire aiming first altitude flight next week goals test engin',
#  'maybe start year depends starship progress goes',
#  '',
#  'definitely need engines make cargo propel',
#  'rapid complete rocket reuse cost propellant orbital refilling propellant production',
#  '',
#  'still simply video control biggest gamechanger',
#  'beta coming days improvement significant',
#  'exciting mission',
#  '',
#  '',
#  'tomorrow flight rocket landing droneship course still love',
#  'sure',
#  'true',
#  'quiet queue products build better roadster pointufc',
#  'fate loves irony hates hypocrisy',
#  'booster separation secondengine start fairing separation useuropean sentinel michael freilich oceanobserving',
#  '',
#  'data center named skynet joke years might tempting fate',
#  'tesla vehicle creating producing many useful products',
#  'largest cast titanium part world heat shielding needed',
#  'landing vandenberg california',
#  'actually side doesnt take launch',
#  '',
#  'investor tesla definitely good company investing',
#  'well almost anything',
#  'quite ahead',
#  'crews view earth dragons flight',
#  'youd call pointy',
#  'cool',
#  'theyre moving times speed sound feels like nothing',
#  '',
#  'always upgrades',
#  'better human vision quite margin',
#  'reality looks like strange ghostworld radar wavelengths',
#  'exactly',
#  'misperception spacex developed continues lidar dragon docking',
#  'starship',
#  'well done',
#  'cant comment turbopump internal details youre roughly ballpark',
#  'clear xpeng problem companies china done',
#  'andrej awesome said talented autopilot',
#  'yeah stole apples code',
#  'version software dont inference computer',
#  'wild times',
#  'congrats',
#  '',
#  '',
#  'change parts otherwise fine',
#  'caution strongly advised spacs',
#  'sure',
#  'haha sexy cropping champion time',
#  'next weeks release looks good widen beta',
#  'unfortunately many rules around liquor distribution even',
#  'next weeks release special fundamental improvements important fixes entire',
#  'years billion',
#  'safety primary design goal',
#  'fully',
#  'martians decide future',
#  'brain space spent dealing units',
#  'terraforming slow relevant lifetime however establish human base',
#  'certainly intention',
#  '',
#  'publicly traded stock tesla',
#  'wise words bogle point companies products services point thems',
#  'mild cold though pclt means viral',
#  'life glass domes first eventually terraformed support life like earth',
#  'yeah',
#  'going seemed obvious haha',
#  'deveras',
#  'cases high noninfectious quarantine days getting another test seco',
#  'many things want didnt know wanted',
#  'maybe little mercy',
#  'tesla holiday software release ufuf',
#  '',
#  'cobra deep',
#  'cake someone took bite',
#  'thing much sentience',
#  'deus machine learning',
#  'designed make life multiplanetary otherwise extreme overkill mere earth sector activity',
#  'like gave blessing sort groundswell believed',
#  'nullius verba',
#  'indeed',
#  'dojodoge',
#  'yeah looks like marginal cost launch less',
#  'exactly',
#  'merlin strong local maximum design kerosene suboptimal fuel matter',
#  'visiting american irony much',
#  'yeah unequivocal doesnt matter',
#  'maybe making notable changes wait figurative literal dust settles',
#  'pretty close definitely feel ufaf take dayquil frankly',
#  'avionics cables moving steel pipe shields adding watercooled steel pipes test',
#  'secs starting engines martyte covering concrete shattered sending blades',
#  'amazing thing rocket engines sometimes dont blow',
#  'count atoms point',
#  'absolutely productiontesting rocket engines',
#  'first merlin engine design really nothing worked well',
#  'maybe love irony haha',
#  'theyre hopefully teslaquila next month',
#  'special permission received stonecutters guild',
#  'fate irony',
#  'well said',
#  '',
#  'damn thats easy spent quite time looking russianukrainian engines theyre good',
#  '',
#  'docking confirmed crew dragon arrived',
#  'toss bitcoin witcher',
#  '',
#  'enter crew dragon nasa crew astronauts give live tour space',
#  'curevac moderna others tesla makes machine curevac uses',
#  'creating synthetic mrna curesvaccines future medicine turns mostly',
#  'haha',
#  'great thread',
#  'thanks asking symptoms past days apart fatigue unless something chang',
#  'uufef',
#  'launch minutes',
#  'yeah cooling channels integrated chamber walls',
#  'propellant used either abort orbital maneuvering obviates',
#  'dragon also hover land propulsively parachutes maximum safety',
#  'thrusters integrated spacecraft enabling abort capability abort increased safety',
#  'song would play ride launch launchamerica',
#  'dragon completed flights designed beginning human spaceflight',
#  'dragon spacecraft currently flying capable returning significant amounts cargo earth first priv',
#  'spacexs customtailored suits route communications cooling systems protect crew event cabin depressu',
#  'live ready launchamerica ufwatch coverage nasa crew mission liftoff',
#  'watch falcon launch crew dragon first operational mission astronauts board',
#  '',
#  'systems tonights launch crew dragons first operational mission four astronauts',
#  'yeah feel pretty normal symptoms right last week',
#  'tests several different labs time administered',
#  'insanely great pointless argument',
#  'astronaut launch today',
#  'message boys girls japan space waiting spotlight astronaut',
#  'weekuf nasas crew astronauts arrive ahead launchuf rover marks days',
#  'spacex nasa crew finished final dress rehearsal getting ready saturday launch behind real dragon',
#  'kids though',
#  'hell collection',
#  'would great labs could give people level granular feedback results',
#  'great question complex question depends test used want',
#  'worth reading thread youre curious rona testing',
#  'blood pressure test tell number',
#  'little feels like regular cold body achy cloudy head',
#  'opinion number gene test probably regarded',
#  '',
#  'cool please super cautious expect steps forward back code merged',
#  'scratch buff',
#  'getting wildly different results different labs likely moderate case covid',
#  'npcs',
#  'ahem',
#  'unless youre',
#  'laws thermodynamics cant cant break even cant stop playing',
#  'shakes fist entropy',
#  'expansion beta program weeks',
#  'interesting thursday night saliva sample came back today gene unique',
#  'whats honey',
#  'feels',
#  'seems accurate',
#  'cold symptoms gone ufufufab',
#  'degrees',
#  'heneghan makes sense hilarious clarify',
#  'number amplification cycles required detect virus rough indicator',
#  'great reference worth read',
#  'case closed',
#  'soon',
#  'fwiw spoke thinks accurate gets dicey talk',
#  'spoke said detection genes cycles reliable cycles',
#  'note spike protein dont consider reliable',
#  'spoke directly testing main search gene unique',
#  'strange',
#  'possible explanation dramatic decline cold prevalence prior years someone comes',
#  'moreover lower true prevalence higher false positive number sounds obvious',
#  '',
#  'sure',
#  'would great hear people know testing industry whats approximate false posi',
#  'interesting',
#  'interesting',
#  'general population knowledge symptoms accuracy sarscov test possible gene',
#  'good test identify spike proteins although heard',
#  'mild sniffles cough slight fever past days right symptoms although take nyquil',
#  'technically tested positive negative twice positive elon musk tests negati',
#  'carousel turns ever faster',
#  '',
#  'exactly',
#  'symptoms typical cold nothing unusual',
#  'happening happening others getting tests separate labs results take hours',
#  'something extremely bogus going tested covid four times today tests came back negative',
#  'burst disk worked vehicle appears well swap least engines',
#  'maybe melted engine preburner fuel manifold whatev',
#  'lost vehicle pneumatics reason unknown present liquid oxygen header tank pressure risin',
#  'ufufufd',
#  'tesla tops list attractive employers engineering students',
#  'astronauts night cape first operational flight crew dragon',
#  'luck best superpower',
#  'thank served sacrificed veteransday',
#  'crew access swings place',
#  '',
#  'honor would choose work strive ensure companies enable',
#  'privilege work people like respect much feel blessed',
#  'flight readiness review crew mission concluded',
#  'falcon crew dragon vertical launch complex',
#  'probably',
#  'happy',
#  'expect become important product world probably financially material tesla',
#  'theres entry',
#  'tesla makes bioreactor make vaccines cures curevac version',
#  'crew dragon falcon hangar launch complex ahead launching four astronauts liftoff',
#  'checking',
#  'hope game doesnt twist tedium fear canceled',
#  'rumor austin chalk geologically best soils tunneling want find austin jobs avai',
#  '',
#  'damn cookie browser setting',
#  'thanks great autopilotai hardware software engineers tesla',
#  'sure',
#  'worth',
#  'exactly',
#  'sure',
#  'actually still',
#  'wait cybertruck',
#  'accidental back shortly',
#  'superchargers counting',
#  'hoping change booster design land back launch mount',
#  'chip temp sensor automatically maintains safe temp',
#  'enough already plate teslas maybe prototy',
#  'neuralink wont overclock brain transfer processing supercomputer extension',
#  'rewrote labeling software different labeling single phot',
#  'version year away',
#  'would appear calculations incorrect',
#  'china understands profound importance reusability expendable rockets soon',
#  'uufefuufef tesla autopilotai team uufefuufef',
#  'good explanation essential dynamically occluded objects especially large intersection',
#  '',
#  'phantom opera inside mind',
#  'ufeufe',
#  'looking problemsolvers things done high sense urgency dont care went school',
#  'sending resume please describe hardest problems solved exactly solved',
#  'banner neededneither hard left right',
#  'another fine simulation',
#  'faraday invented electric motor tesla commutatorfree threephase induction motor',
#  'maxwell amazing recognition tesla motors almost called faraday',
#  'times better',
#  '',
#  'deployment confirmed',
#  'falcon first stage lands course still love droneship',
#  'liftoff',
#  'awaiting approval canadian authorities',
#  'recruiting engineers giga berlin interview person tomorrow site send resume guns',
#  'stop chad',
#  'chad',
#  'einstein great succeed engineering tried',
#  'yeah relatively easy users ocean',
#  'although didnt expect stock rise much',
#  'super appreciate support steve convertible loan gave months runway',
#  'closest month model ramp extreme stress',
#  'last money even though thought would still fail eithe',
#  'funding round completed christmas last hour last possible investo',
#  '',
#  'lowering starlink terminal cost sound rather pedestrian actually difficult technical challenge',
#  'soon regulatory approval hopefully around middle next year',
#  'right takes mins future improvements probably less',
#  'canada norway next early beta',
#  'didnt realize possible problem theres current design cybertruck approved europe',
#  'soon country approval required country individually euwide approval',
#  'lower latitude states need satellites position probably january',
#  'several thousand starlink beta participation invitations going week',
#  'design better many minor tweaks even small details matter',
#  'haha',
#  'close actual expected flight',
#  'could excited supercollider said considerably larger',
#  '',
#  '',
#  'tesla',
#  '',
#  'penguin random house change name random penguinuf',
#  'sure although might quite short livestream wrong well provide video',
#  'matters',
#  'weve tested subscale version wind tunnel active aero clos',
#  '',
#  'lord',
#  'yeah although fails right landing',
#  'minor',
#  'understanding exactly body flaps control pitch roll duri',
#  'right launch also possible fortunately almost ready',
#  'stable controlled descent body flaps would great transferring propellant',
#  'every days',
#  'faults never zero point probability fault',
#  'measure primarily intervention probability update addressed several issu',
#  'thanks great autopilotai team working super hard neural nets without testing',
#  'latency improve significantly soon bandwidth',
#  'build noticeably better interventions',
#  '',
#  'spent half life california love state frankly think',
#  'sweden still right zero deaths',
#  'true also fewer heart attacks easier pump blood gravity',
#  'talking also stephenson constellation scrotum haha',
#  'small converts million tons mass energy every second',
#  'accurate',
#  '',
#  'challenges high winds looks like sunday static fire',
#  'great shot',
#  'future appreciate',
#  'truth stranger fiction',
#  '',
#  'smol',
#  'long time',
#  'truth told eaten jitb many times years even teriyaki bowl',
#  'might jack footstool',
#  'approximately lograte',
#  'change setting combat',
#  'well phased array antenna actually rather flat',
#  'tesla make catgirl robots',
#  'little crane',
#  'ufuf',
#  'come come',
#  'mayo sure salty',
#  'payne great many levels silent hill good',
#  'jack double duty sperm donor clinic name',
#  'best games ever',
#  'fear modern graphics sound would rock',
#  '',
#  'games thread scarier creatively horror movie',
#  'fear best also dead space haunt dreams',
#  '',
#  'best knowledge literally zero equipment usable without major repairs upgra',
#  'left broken bots equipment hardly worth scrap metal value scrounged',
#  'actually zero employees factory gmtoyota left took good equipment',
#  'bettern nothin back',
#  'ufab',
#  'tesla team done great work',
#  'well capex efficiency trash',
#  'testing covid license print money',
#  'helpful thanks beta testers',
#  'video training inference essential excellent autonomy',
#  'sigh supersonic time electric',
#  'critical humanitys future',
#  'congratulations spacex team',
#  'mine days ahead',
#  'sure could option settings',
#  'visualization tone significantly production intentionally strident colors',
#  'sure',
#  'boca every week maybe could talk',
#  'good point probably next week form written piece spacex website',
#  'great pics beginnings starship production system meaningful',
#  'beta updates therell steps step back situations pace improv',
#  'working also needs able fart cars command',
#  'starship coming together',
#  'price change pushed thursday next week applies week clock start countr',
#  'glass star name high',
#  'well said many times price rise product functionality improves much',
#  'agreed performance tires',
#  'smallseeming issue loss upper stage camera probably nothing serious standing',
#  'sure',
#  'tesla beta limited release price upgrade monday',
#  'soon complete testing regulators approve many differe',
#  '',
#  'haha',
#  'dependent proving high safety',
#  'intentional wanted show could theoretically convert entire vehicle',
#  'cold later',
#  'mean gotta tiki',
#  'starship nosecone high tiki',
#  '',
#  'gets orbit times',
#  'little melty',
#  'engines could would dicey pushing nearterm tests doesnt achieve',
#  'raptor secs chamber pressure encountering issues',
#  'beta rollout happening tonight extremely slow cautious',
#  'data engine starship static fire morning looks good proceeding nosecone mate',
#  'also consider population lifemonths lost lockdowns restriction',
#  'sweden zero deaths',
#  '',
#  'firmware probably slightly accurate description',
#  'theres place like homeespecially solar roofthis kansas ranch installed days',
#  'mobic much mobility fusion little need mobid haha',
#  'actually neck',
#  'maybe helpful mobic disc however surgery failed remov',
#  'pretty accurate much sequencing using synthetic dnarna bugs code',
#  'london beijing would cool',
#  'would quite trip',
#  'thats haha',
#  'trnd',
#  'looks like snoopy',
#  'current production slightly better',
#  'doesnt seem life solar system maybe europa',
#  'tesla model lowest energy consumption bevs says report',
#  'creative',
#  'free fusion reactor conveniently converts million tons mass energy every second',
#  'never know',
#  '',
#  '',
#  'also system autodelete data automatically default',
#  'table tension',
#  '',
#  'starting production seater next month initial deliveries early december',
#  'gauntlet thrown prophecy fulfilled model price changes tonight',
#  '',
#  'congratulations',
#  'making progress',
#  'meter roughly diameter',
#  'less roomy vacuum rocket engines added',
#  'still focus vegas prufrock tunneling machine',
#  'sure',
#  'maybe month finishing touches need done stations',
#  'simplified basically teslas tunnels point',
#  'sweet',
#  'everything slow phased array antenna',
#  'nice',
#  'love baby dont hurt winston churchill',
#  'maybe weak turrets allow strategic degrees freedom',
#  'please buff torbs turret',
#  '',
#  'goosebumps merch sure',
#  '',
#  'lotr',
#  'illuminaughty',
#  'knee deep',
#  'first flight upgraded cargo version dragon able carry science payloads',
#  'dragon spacecraft supporting spacexs cargo resupply mission departed hawthorne factory last',
#  'yeah',
#  'least success possible outcomes time',
#  'diess best move right direction tough position',
#  'good grief spacex getting zero money starship designed carry people cargo around',
#  'stuck local maximums wasnt clear ceiling time right',
#  'thank much accurate haha',
#  'graph appears upside',
#  'sheer magnitude entire production system hard appreciate almost every element productio',
#  'release order configurator probably',
#  'limited beta releasing tuesday next week promised first limited',
#  ...]

# %%
# Joining the list into one string/text
tweets_merge = ' '.join(tweets_merge)
tweets_merge
# Out:
# 'alien tracing cyberpunk nextlevel tried great interview doge underestimated congratulations tesla china amazing execution last year next even happy year frodo underdogeall thought would failhimself haha thanks indeed tweets definitely represent realworld time allocation entertaining outcome likely sent agree clubhouse  getting real bought dogecoin toddler hodler definitely issues sentencing seems high thanks fixing please unlock account ufuf true power haha crypto wallet wont give private keys avoided costs sucks nasa selected falcon heavy launch first elements lunar gateway together mission  predict cash flow reasonably well starlink starlink staggeringly difficult technical economic endeavor however spacex needs pass deep chasm negative cash flow next year lowest cost carbon sequestered value product made must scalable meant price countries difference taxes shipping intended earth ideas apply mars ufuf xprize team manage carbon capture prize everyone tesla receives stock comp stockoptions take table thats youre missing back work seem high doge appears inflationary meaningfully fixed coins unit time whereas  orbital launch tower stack enough raptors orbit booster improve ship booster mass back work tonight ogecoin instructional video people spoken cute extremely misleading image doesnt reflect true time cost people rain pain doge hodl rainforests finally come crypto simplicity genius  ufuf true ufuf easy decades intense work look notes emails texts  lessons learned earth mars time tell story tesla spacex read great second last kingdom havent heard name years dogecake yolt thats damian yeah sure great thing restaurants hang strangers future currency earth scratch much  destiny franz essential said ship landing burn clear solution greate still maneuvering thrusters higher intuitively would seem turbopumpfed raptors  falcon launch spherex mission collect data million galaxies explore falcon launches starlink satellites orbit mission deck true yeah default engine least lever would shut good engines throttle point flameout risk  foolish start engines immediately shut needed land become memedestroyer shorts might actually happen sandstorm masterpiece dumb next time pull method lowkey loki highs lows doge need gigachad dogecoin peoples crypto welcome entertaining outcome likely doge  high seas wind tough watch falcon launch starlink satellites twitter filled graffiti ucub uuuubuuuc giga berlin progress neuralink working super hard ensure implant safety close communication mission enables access everyday people dream going space announcing first commercial astronaut mission orbit earth aboard dragon youve worked advanced wearables phones robots skills needed feels weird helping make hopefully good version cyberpunk come true please consider working neuralinkshortterm solve brainspine injurieslongterm humanai symbiosis latte  clubhouse tonight time great stories experim launch alert targeting earlier april launch second crew rotation became methane sounds correct certainly deserves great instrumental developing early vers accelerate unusually fast high important reusable escaping read whole article ufuf warm sunny snowy mountains beautiful yeah frankensteen never used gave talk spacex halo  sure hope thats true tesla spacex cryoproof install engines starship retrospect inevitable great shot live sword sword entropy hold companies make goods produce services love earth small smaller still  cyberpunk even hotfixes literally hotfixes great game  dollar shorting indeed shopify great spacex used ufuf indeed economy making useful products providing great services actually matters tanstaafl would better small fees fees latter makes robin come shorty apologistsgive respectget shorty cant sell houses dont ownu cant sell cars dont ownbut sell stock dont ownthis  finishing engineering year production starts next year aiming release candidate desig made video absolutely unlike aircraft division fine space division fundamentally broken nomad  est ...

# %%
from nltk import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

tweet_lemmas = [lemmatizer.lemmatize(t,'v') for t in tweets_merge.split()]
print(tweet_lemmas)
# Out:
# ['alien', 'trace', 'cyberpunk', 'nextlevel', 'try', 'great', 'interview', 'doge', 'underestimate', 'congratulations', 'tesla', 'china', 'amaze', 'execution', 'last', 'year', 'next', 'even', 'happy', 'year', 'frodo', 'underdogeall', 'think', 'would', 'failhimself', 'haha', 'thank', 'indeed', 'tweet', 'definitely', 'represent', 'realworld', 'time', 'allocation', 'entertain', 'outcome', 'likely', 'send', 'agree', 'clubhouse', 'get', 'real', 'buy', 'dogecoin', 'toddler', 'hodler', 'definitely', 'issue', 'sentence', 'seem', 'high', 'thank', 'fix', 'please', 'unlock', 'account', 'ufuf', 'true', 'power', 'haha', 'crypto', 'wallet', 'wont', 'give', 'private', 'key', 'avoid', 'cost', 'suck', 'nasa', 'select', 'falcon', 'heavy', 'launch', 'first', 'elements', 'lunar', 'gateway', 'together', 'mission', 'predict', 'cash', 'flow', 'reasonably', 'well', 'starlink', 'starlink', 'staggeringly', 'difficult', 'technical', 'economic', 'endeavor', 'however', 'spacex', 'need', 'pass', 'deep', 'chasm', 'negative', 'cash', 'flow', 'next', 'year', 'lowest', 'cost', 'carbon', 'sequester', 'value', 'product', 'make', 'must', 'scalable', 'mean', 'price', 'countries', 'difference', 'tax', 'ship', 'intend', 'earth', 'ideas', 'apply', 'mar', 'ufuf', 'xprize', 'team', 'manage', 'carbon', 'capture', 'prize', 'everyone', 'tesla', 'receive', 'stock', 'comp', 'stockoptions', 'take', 'table', 'thats', 'youre', 'miss', 'back', 'work', 'seem', 'high', 'doge', 'appear', 'inflationary', 'meaningfully', 'fix', 'coin', 'unit', 'time', 'whereas', 'orbital', 'launch', 'tower', 'stack', 'enough', 'raptors', 'orbit', 'booster', 'improve', 'ship', 'booster', 'mass', 'back', 'work', 'tonight', 'ogecoin', 'instructional', 'video', 'people', 'speak', 'cute', 'extremely', 'mislead', 'image', 'doesnt', 'reflect', 'true', 'time', 'cost', 'people', 'rain', 'pain', 'doge', 'hodl', 'rainforests', 'finally', 'come', 'crypto', 'simplicity', 'genius', 'ufuf', 'true', 'ufuf', 'easy', 'decades', 'intense', 'work', 'look', 'note', 'email', 'texts', 'lessons', 'learn', 'earth', 'mar', 'time', 'tell', 'story', 'tesla', 'spacex', 'read', 'great', 'second', 'last', 'kingdom', 'havent', 'hear', 'name', 'years', 'dogecake', 'yolt', 'thats', 'damian', 'yeah', 'sure', 'great', 'thing', 'restaurants', 'hang', 'strangers', 'future', 'currency', 'earth', 'scratch', 'much', 'destiny', 'franz', 'essential', 'say', 'ship', 'land', 'burn', 'clear', 'solution', 'greate', 'still', 'maneuver', 'thrusters', 'higher', 'intuitively', 'would', 'seem', 'turbopumpfed', 'raptors', 'falcon', 'launch', 'spherex', 'mission', 'collect', 'data', 'million', 'galaxies', 'explore', 'falcon', 'launch', 'starlink', 'satellite', 'orbit', 'mission', 'deck', 'true', 'yeah', 'default', 'engine', 'least', 'lever', 'would', 'shut', 'good', 'engines', 'throttle', 'point', 'flameout', 'risk', 'foolish', 'start', 'engines', 'immediately', 'shut', 'need', 'land', 'become', 'memedestroyer', 'short', 'might', 'actually', 'happen', 'sandstorm', 'masterpiece', 'dumb', 'next', 'time', 'pull', 'method', 'lowkey', 'loki', 'highs', 'low', 'doge', 'need', 'gigachad', 'dogecoin', 'people', 'crypto', 'welcome', 'entertain', 'outcome', 'likely', 'doge', 'high', 'seas', 'wind', 'tough', 'watch', 'falcon', 'launch', 'starlink', 'satellite', 'twitter', 'fill', 'graffiti', 'ucub', 'uuuubuuuc', 'giga', 'berlin', 'progress', 'neuralink', 'work', 'super', 'hard', 'ensure', 'implant', 'safety', 'close', 'communication', 'mission', 'enable', 'access', 'everyday', 'people', 'dream', 'go', 'space', 'announce', 'first', 'commercial', 'astronaut', 'mission', 'orbit', 'earth', 'aboard', 'dragon', 'youve', 'work', 'advance', 'wearables', 'phone', 'robots', 'skills', 'need', 'feel', 'weird', 'help', 'make', 'hopefully', 'good', 'version', 'cyberpunk', 'come', 'true', 'please', 'consider', 'work', 'neuralinkshortterm', 'solve', 'brainspine', 'injurieslongterm', 'humanai', 'symbiosis', 'latte', 'clubhouse', 'tonight', 'time', 'great', 'stories', 'experim', 'lau ...

# %% [markdown]
# # Counting positive and negative opinion words from the corpus supplied

# %%
## loading the positive and negative emotions list
positive_words=pd.read_csv('E://EXCELR//Data science//Data science assignment//11) Text Mining//positive-words.txt',encoding='latin-1',sep='delimiter',header=None,engine='python')
negative_words=pd.read_csv('E://EXCELR//Data science//Data science assignment//11) Text Mining//negative-words.txt',encoding='latin-1',sep='delimiter',header=None,engine='python')

# %%
positive_words.head()
# Out:
#                                                                               0
# 0  ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 1                                                                             ;
# 2                                                   ; Opinion Lexicon: Positive
# 3                                                                             ;
# 4   ; This file contains a list of POSITIVE opinion words (or sentiment words).

# %%
negative_words.head()
# Out:
#                                                                                 0
# 0  ;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;
# 1                                                                               ;
# 2                                                     ; Opinion Lexicon: Negative
# 3                                                                               ;
# 4     ; This file contains a list of NEGATIVE opinion words (or sentiment words).

# %%
## stripping white spaces
positive_words = [w.strip() for w in positive_words[0]] 
negative_words = [w.strip() for w in negative_words[0]]

# %%
print(positive_words[0:10])
print(negative_words[0:10])
# Out:
# [';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;', ';', '; Opinion Lexicon: Positive', ';', '; This file contains a list of POSITIVE opinion words (or sentiment words).', ';', '; This file and the papers can all be downloaded from', ';    http://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html', ';', '; If you use this list, please cite one of the following two papers:']
# [';;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;;', ';', '; Opinion Lexicon: Negative', ';', '; This file contains a list of NEGATIVE opinion words (or sentiment words).', ';', '; This file and the papers can all be downloaded from', ';    http://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html', ';', '; If you use this list, please cite one of the following two papers:']

# %%
print('Total positive words in supplied corpus:',len(positive_words))
print('Total negative words in supplied corpus:',len(negative_words))
# Out:
# Total positive words in supplied corpus: 2040
# Total negative words in supplied corpus: 4817

# %%
positive_list=[]
negative_list=[]
for word in tweet_lemmas:
    if word in positive_words:
        positive_list.append(word)
    if word in negative_words:
        negative_list.append(word)

# %%
print("Total positive words in tweets:",len(positive_list))
print("Total negative words in tweets:",len(negative_list))
# Out:
# Total positive words in tweets: 863
# Total negative words in tweets: 428

# %%
from collections import Counter

# %%
pos_f= Counter(positive_list)
print(pos_f)
# Out:
# Counter({'great': 76, 'good': 51, 'work': 49, 'like': 39, 'well': 29, 'thank': 24, 'better': 23, 'right': 23, 'best': 23, 'pretty': 22, 'cool': 21, 'love': 17, 'super': 16, 'support': 14, 'important': 13, 'appreciate': 13, 'fair': 12, 'accurate': 12, 'enough': 11, 'amaze': 10, 'improve': 10, 'improvements': 10, 'congratulations': 9, 'easy': 8, 'progress': 8, 'fast': 8, 'fine': 7, 'awesome': 7, 'worth': 7, 'safe': 7, 'welcome': 6, 'glad': 6, 'impressive': 6, 'happy': 5, 'tough': 5, 'useful': 5, 'approval': 5, 'positive': 5, 'faster': 5, 'favorite': 5, 'clear': 4, 'incredible': 4, 'reliable': 4, 'excite': 4, 'nice': 4, 'successful': 4, 'improvement': 4, 'entertain': 3, 'reasonably': 3, 'correct': 3, 'sensible': 3, 'wise': 3, 'promise': 3, 'success': 3, 'significant': 3, 'ready': 3, 'prize': 2, 'cute': 2, 'destiny': 2, 'warm': 2, 'beautiful': 2, 'exceptionally': 2, 'smart': 2, 'sustainable': 2, 'free': 2, 'proud': 2, 'inspire': 2, 'autonomous': 2, 'capable': 2, 'cure': 2, 'magic': 2, 'quiet': 2, 'wonder': 2, 'rapid': 2, 'sexy': 2, 'champion': 2, 'bless': 2, 'strong': 2, 'protect': 2, 'honor': 2, 'succeed': 2, 'approve': 2, 'stable': 2, 'easier': 2, 'modern': 2, 'usable': 2, 'helpful': 2, 'excellent': 2, 'advantage': 2, 'mature': 2, 'efficient': 2, 'exceptional': 2, 'win': 2, 'guarantee': 2, 'boost': 2, 'satisfy': 2, 'genius': 1, 'masterpiece': 1, 'instrumental': 1, 'upgradable': 1, 'catchy': 1, 'affordable': 1, 'fresh': 1, 'valuable': 1, 'ease': 1, 'distinction': 1, 'optimistic': 1, 'futuristic': 1, 'classic': 1, 'greatest': 1, 'merry': 1, 'accessible': 1, 'bright': 1, 'confident': 1, 'soft': 1, 'precise': 1, 'fastest': 1, 'magical': 1, 'award': 1, 'robust': 1, 'tempt': 1, 'talented': 1, 'mercy': 1, 'unequivocal': 1, 'capability': 1, 'regard': 1, 'hilarious': 1, 'top': 1, 'attractive': 1, 'luck': 1, 'privilege': 1, 'respect': 1, 'profound': 1, 'fortunately': 1, 'silent': 1, 'meaningful': 1, 'creative': 1, 'conveniently': 1, 'roomy': 1, 'simplify': 1, 'sweet': 1, 'freedom': 1, 'rich': 1, 'lead': 1, 'aspire': 1, 'competitive': 1, 'inspiration': 1, 'fairly': 1, 'subsidize': 1, 'outstanding': 1, 'appeal': 1, 'achievement': 1, 'stainless': 1, 'hug': 1, 'gain': 1, 'excitement': 1, 'prefer': 1, 'pure': 1, 'talent': 1, 'smoother': 1, 'trust': 1, 'recommendation': 1, 'reasonable': 1, 'brave': 1, 'calm': 1, 'reliably': 1, 'grateful': 1, 'recovery': 1, 'perfectly': 1, 'efficiently': 1, 'fabulous': 1, 'clearly': 1, 'smooth': 1, 'recommend': 1, 'assure': 1, 'cherish': 1, 'simplest': 1, 'incredibly': 1, 'lover': 1, 'humor': 1, 'energetic': 1, 'whoa': 1, 'happiness': 1, 'favor': 1, 'revolutionary': 1, 'remarkably': 1, 'insightful': 1, 'optimal': 1, 'perseverance': 1, 'paramount': 1, 'sustainability': 1, 'surreal': 1})

# %%
import collections
pos_10=pos_f.most_common(10)
print("Top 10 frequent positive words:\n",pos_10)
# Out:
# Top 10 frequent positive words:
#  [('great', 76), ('good', 51), ('work', 49), ('like', 39), ('well', 29), ('thank', 24), ('better', 23), ('right', 23), ('best', 23), ('pretty', 22)]

# %%
type(pos_10)
# Out:
# list

# %%
pos_10=dict(pos_10)
print(pos_10)
# Out:
# {'great': 76, 'good': 51, 'work': 49, 'like': 39, 'well': 29, 'thank': 24, 'better': 23, 'right': 23, 'best': 23, 'pretty': 22}

# %%
neg_f=Counter(negative_list)
print(neg_f)
# Out:
# Counter({'mar': 19, 'hard': 18, 'slow': 11, 'static': 9, 'tank': 8, 'problems': 8, 'sorry': 7, 'cold': 7, 'problem': 6, 'critical': 6, 'irony': 6, 'symptoms': 6, 'lose': 6, 'limit': 6, 'burn': 5, 'wild': 5, 'crazy': 5, 'false': 5, 'issue': 4, 'negative': 4, 'dumb': 4, 'break': 4, 'unfortunately': 4, 'strange': 4, 'blow': 4, 'impossible': 4, 'complex': 4, 'fail': 4, 'suck': 3, 'difficult': 3, 'hang': 3, 'risk': 3, 'hell': 3, 'fallout': 3, 'twist': 3, 'bug': 3, 'wrong': 3, 'incorrect': 3, 'bore': 3, 'abort': 3, 'fear': 3, 'attack': 3, 'loss': 3, 'pain': 2, 'intense': 2, 'scratch': 2, 'foolish': 2, 'weird': 2, 'inevitable': 2, 'trap': 2, 'discord': 2, 'steal': 2, 'suicide': 2, 'fall': 2, 'opposition': 2, 'nightmare': 2, 'knock': 2, 'marginal': 2, 'damn': 2, 'pointless': 2, 'wildly': 2, 'virus': 2, 'decline': 2, 'rumor': 2, 'fault': 2, 'latency': 2, 'trash': 2, 'tension': 2, 'die': 2, 'mistake': 2, 'crash': 2, 'rail': 2, 'insane': 2, 'error': 2, 'jam': 2, 'trivial': 2, 'worst': 2, 'sting': 2, 'absurd': 2, 'danger': 2, 'underestimate': 1, 'miss': 1, 'inflationary': 1, 'mislead': 1, 'throttle': 1, 'unusually': 1, 'annoy': 1, 'hedge': 1, 'tyranny': 1, 'grind': 1, 'confusion': 1, 'unfavorable': 1, 'toxic': 1, 'knife': 1, 'hate': 1, 'junkyard': 1, 'unhappy': 1, 'sick': 1, 'ignore': 1, 'wack': 1, 'trouble': 1, 'hazard': 1, 'sneaky': 1, 'grumpy': 1, 'absurdly': 1, 'stun': 1, 'absence': 1, 'risky': 1, 'savage': 1, 'hypocrisy': 1, 'joke': 1, 'overkill': 1, 'dust': 1, 'shatter': 1, 'fatigue': 1, 'insanely': 1, 'cloudy': 1, 'shake': 1, 'fist': 1, 'rough': 1, 'fever': 1, 'unusual': 1, 'bogus': 1, 'unknown': 1, 'accidental': 1, 'occlude': 1, 'object': 1, 'stress': 1, 'stranger': 1, 'fiction': 1, 'scarier': 1, 'dead': 1, 'haunt': 1, 'scrap': 1, 'strident': 1, 'restriction': 1, 'hurt': 1, 'weak': 1, 'grief': 1, 'poor': 1, 'sketchy': 1, 'failure': 1, 'crush': 1, 'costly': 1, 'bankrupt': 1, 'agony': 1, 'burden': 1, 'dense': 1, 'louder': 1, 'unexpected': 1, 'thicker': 1, 'suspect': 1, 'emergency': 1, 'inaccurate': 1, 'ludicrous': 1, 'difficulty': 1, 'incorrectly': 1, 'overlook': 1, 'utterly': 1, 'irrational': 1, 'funny': 1, 'obscure': 1, 'warp': 1, 'tricky': 1, 'moron': 1, 'lurch': 1, 'bombard': 1, 'embarrass': 1, 'overweight': 1, 'unlikely': 1, 'obtuse': 1, 'lengthy': 1, 'freeze': 1, 'strike': 1, 'noise': 1, 'farcical': 1, 'dirt': 1, 'explode': 1, 'beg': 1, 'hasty': 1, 'worry': 1, 'embarrassingly': 1, 'bump': 1, 'madness': 1, 'distract': 1, 'confess': 1, 'untrue': 1, 'damage': 1, 'corrosion': 1, 'resistance': 1, 'topple': 1, 'fool': 1, 'drag': 1, 'steep': 1, 'excuse': 1, 'negativity': 1, 'bias': 1, 'obtrusive': 1, 'unsecure': 1, 'collapse': 1, 'difficulties': 1, 'paranoid': 1, 'unacceptably': 1, 'death': 1, 'dire': 1, 'propaganda': 1})

# %%
neg_10=neg_f.most_common(10)
print("Top 10 frequent negative words:\n",neg_10)
# Out:
# Top 10 frequent negative words:
#  [('mar', 19), ('hard', 18), ('slow', 11), ('static', 9), ('tank', 8), ('problems', 8), ('sorry', 7), ('cold', 7), ('problem', 6), ('critical', 6)]

# %%
neg_10=dict(neg_10)
print(neg_10)
# Out:
# {'mar': 19, 'hard': 18, 'slow': 11, 'static': 9, 'tank': 8, 'problems': 8, 'sorry': 7, 'cold': 7, 'problem': 6, 'critical': 6}

# %%
## Plotting top 10 positive words
fig,ax=plt.subplots(1,2,figsize=(15,5))

ax[0].bar(pos_10.keys(),pos_10.values())
ax[1].bar(neg_10.keys(),neg_10.values())

ax[0].set_title('Top 10 positive words present in tweets')
ax[1].set_title('Top 10 negative words present in tweets')

fig.autofmt_xdate()

plt.show()

# %%
## Combining both positive and negative emotions in a single list
emotion_list=positive_list+negative_list
print(emotion_list[0:15])
# Out:
# ['great', 'congratulations', 'amaze', 'happy', 'thank', 'entertain', 'thank', 'reasonably', 'well', 'prize', 'work', 'enough', 'improve', 'work', 'cute']

# %%
## Counting frequency of words in emotion_list
emo_f= Counter(emotion_list)

# First 10 frequent words/emotions
emo_10= emo_f.most_common(10)
print(emo_10)
# Out:
# [('great', 76), ('good', 51), ('work', 49), ('like', 39), ('well', 29), ('thank', 24), ('better', 23), ('right', 23), ('best', 23), ('pretty', 22)]

# %%
## Plotting the most frequent words in tweets

# Converting list to dict
emo_10=dict(emo_10)

fig,ax=plt.subplots()

ax.bar(emo_10.keys(),emo_10.values())
fig.autofmt_xdate()
plt.show()

# %% [markdown]
# # Using Textblob for sentiment analysis

# %%
from textblob import TextBlob

# %%
type(tweet_lemmas)
# Out:
# list

# %%
tweets_join=' '.join(tweet_lemmas)
tweets_join[0:100]
# Out:
# 'alien trace cyberpunk nextlevel try great interview doge underestimate congratulations tesla china a'

# %%
tweet_blob= TextBlob(tweets_join)
tweet_blob.sentiment
# Out:
# Sentiment(polarity=0.19019508106272776, subjectivity=0.5150267444973315)

# %% [markdown]
# # Using Vader Sentiment Intensity Analyzer

# %%
#nltk.download('vader_lexicon')

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
si = SentimentIntensityAnalyzer()
sentiment_score = si.polarity_scores(tweets_join)
sentiment_score
# Out:
# {'neg': 0.063, 'neu': 0.657, 'pos': 0.28, 'compound': 1.0}

# %% [markdown]
# Both Textblob and Vader shows an overall positive sentiment in tweets.
